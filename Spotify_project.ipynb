# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_data = pd.read_csv(r'C:\Users\saurabh bohra\Documents\project\tracks.csv')

# %%
df_data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
df_data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_data.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
sorted_values = df_data.sort_values('popularity', ascending = True)

# %%
sorted_values.set_index("release_date",inplace = True)

# %%
sorted_values
# Out:
#                                   id  \
# release_date
# 1935-02-20    181rTRhCcggZPwP2TUcVqm
# 1949          0yOCz3V5KMm8l1T8EFc60i
# 1949          0y48Hhwe52099UqYjegRCO
# 1949          0xCmgtf9ka07hkZg3D6PaV
# 1949          0tBXS3VuCPX7KWUFH2nros
# ...                              ...
# 2020-12-04    6tDDoYIxWvMLTdKpjFkc1B
# 2020-03-20    5QO79kh1waicV47BqGRL3g
# 2021-01-06    3Ofmpyhv5UAQ70mENzB277
# 2021-01-08    7lPN2DXiMsVn7XUKtOW1CS
# 2021-03-19    4iJyoBOLtHqaGxP12qzhQI
#
#                                                       name  popularity  \
# release_date
# 1935-02-20    Newspaper Reports On Abner, 20 February 1935           0
# 1949                                                恋は水の上で           0
# 1949                                                 私の誕生日           0
# 1949                                   エル・チョクロ (EL CHOCLO)           0
# 1949                                              恋は不思議なもの           0
# ...

# %%
sorted_values[sorted_values['popularity']>90].sort_values('popularity', ascending = False)
sorted_values[:10]
# Out:
#                                   id  \
# release_date
# 1935-02-20    181rTRhCcggZPwP2TUcVqm
# 1949          0yOCz3V5KMm8l1T8EFc60i
# 1949          0y48Hhwe52099UqYjegRCO
# 1949          0xCmgtf9ka07hkZg3D6PaV
# 1949          0tBXS3VuCPX7KWUFH2nros
# 1949          0qrKnQtYDVJhKFAXTHYVS9
# 1949-04-10    0nqsDxOeKSwEzp3AUQAAqS
# 1949          0kGEdsxVLYjCdfxM9tbezd
# 1949-05-19    0bc3PUZurUUXrY7yqoOxjq
# 1949-05-08    0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                            name  popularity  \
# release_date
# 1935-02-20         Newspaper Reports On Abner, 20 February 1935           0
# 1949                                                     恋は水の上で           0
# 1949                                                      私の誕生日           0
# 1949                                        エル・チョクロ (EL CHOCLO)           0
# 1949                                                   恋は不思議なもの           0
# ...

# %%
plt.figure(figsize= (10,6))
sns.regplot(data= df_data , y = "loudness" ,  x = "energy" , color = "c")

# %%
df_data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
df_genre = pd.read_csv(r'C:\Users\saurabh bohra\Documents\project\SpotifyFeatures.csv')

# %%
df_genre
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
plt.title("Duration of songs in Different Genres")
sns.barplot(y = 'genre' , x='duration_ms' , data = df_genre)
plt.xlabel("duration in milli second" , color = 'g')
plt.ylabel("genre" , color = 'g')
# Out:
# Text(0, 0.5, 'genre')

# %%
famous = df_genre.sort_values("popularity", ascending = False).head(10)
sns.barplot(y = 'genre' , x = 'popularity' , data = famous)
